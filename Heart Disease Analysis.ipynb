# %% [markdown]
# # **1. Import the Libraries and Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Data takes as pandas.read(). It read csv file by pd.read_csv.

# %%
data = pd.read_csv('heart.csv')

# %% [markdown]
# # **2. Display top 5 rows of Dataset**

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # **Description of all the columns are following below :-**

# %% [markdown]
# **>age**
#
# **>sex**
#
# **>chest pain type(4 values)**
#
#    **■ Value 0: typical angina**
#
#    **■ Value 1: atypical angina**
#
#    **■ Value 2: non-anginal pain**
#
#    **■ Value 3: asymptomatic**
#
# **>trestbps: resting blood pressure(in mm Hg on admission to the hospital)**
#
# **>chol: serum cholstoral in mg/dl**
#
# **>fbs:fasting blood sugar > 120mg/dl(1=true and 0=false)**
#
# **>restecg: resting electrocardiographic results**
#
#    **■ Value 0: normal**
#
#    **■ Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)**
#
#    **■ Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria**
#
# **>thalach: maximum heart rate achieved**
#
# **>exang: exercise induced angina (1 = yes; 0 = no)**
#
# **>oldpeak = ST depression induced by exercise relative to rest**
#
# **>slope: the slope of the peak exercise ST segment**
#
#    **■ Value 1: upsloping**
#
#    **■ Value 2: flat**
#
#    **■ Value 3: downsloping**
#
# **>ca: number of major vessels (0-3) colored by flourosopy**
#
# **>thal: 3 = normal; 6 = fixed defect; 7 = reversable defect**
#
# **>target: 0=less chance of heart attack, 1=more chance of heart attack**

# %% [markdown]
# # **3. Check the last 5 rows of the dataset.**

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# # **4. Find the shape of our dataset(Number of rows and columns)**

# %%
data.shape
# Out:
# (1025, 14)

# %%
print("Number of rows",data.shape[0])
print("Number of columns",data.shape[1])
# Out:
# Number of rows 1025
# Number of columns 14

# %% [markdown]
# # **5. Get Information about our Dataset like Total Numbers of Rows,Total Number of Columns , Datatype of each Column and Memory Requirement**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # **6. Check Null Values in the Dataset**

# %%
 data.isnull()
# Out:
#         age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0     False  False  False     False  False  False    False    False  False
# 1     False  False  False     False  False  False    False    False  False
# 2     False  False  False     False  False  False    False    False  False
# 3     False  False  False     False  False  False    False    False  False
# 4     False  False  False     False  False  False    False    False  False
# ...     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 1020  False  False  False     False  False  False    False    False  False
# 1021  False  False  False     False  False  False    False    False  False
# 1022  False  False  False     False  False  False    False    False  False
# 1023  False  False  False     False  False  False    False    False  False
# 1024  False  False  False     False  False  False    False    False  False
#
#       oldpeak  slope     ca   thal  target
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# **Here all are zeros shows .There is no null values across the column.**

# %% [markdown]
# # **7. Check for duplicates Data**

# %%
data_dup = data.duplicated().any()
print(data_dup)
# Out:
# True

# %% [markdown]
# **Dupicates data are here thats why its givinf true**

# %% [markdown]
# # Drop duplicates data

# %%
data= data.drop_duplicates()

# %% [markdown]
# **Check duplicates data is removed or not through no. of Rows**

# %%
data.shape
# Out:
# (302, 14)

# %% [markdown]
# **Original data had (1025, 14) rows and column respectively but after drop the duplicate data , data has (302, 14) rows and columns respectively**

# %% [markdown]
# # **8. Get Overall Statistics about the Dataset**

# %%
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # **9. Draw Correlation Matrix**

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %% [markdown]
# **TO Visualize this data by Seaborn libraries in other manner**

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %% [markdown]
# **Let me change the size correlation matrix plot**

# %%
plt.figure(figsize=(17,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # **10. How many People have Heart Disease and How many don't have Heart Disease in this Dataset?**

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# **To Check target values if (value=0 then No Heart disease) and (value=1 and Heart disease).**

# %%
data['target'].value_counts()

# %% [markdown]
# **Here target value(0)== 138 that means 138 people have heart disease.**

# %% [markdown]
# **TO present this value in graphical then we use seaborn**

# %%
sns.countplot(x='target', data=data, palette=custom_palette)
# Out:
# /var/folders/ss/_99xspms5kx2w1n6qb7bmdsh0000gn/T/ipykernel_67758/2160586619.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='target', data=data, palette=custom_palette)
# <Axes: xlabel='target', ylabel='count'>

# %%
  custom_palette = ['#1f77b4', '#ff7f0e']# Blue and Yellow colors

plot = sns.countplot(x='target', data=data, palette=custom_palette)

# Adding labels for clarity
plt.xlabel('Target')
plt.ylabel('Count')
plt.title('Count of Target Values')
plt.xticks([0,1],['Normal People','Patient'])


# Adding the exact numbers on top of the bars
for p in plot.patches:
    plot.annotate(format(p.get_height(), '.0f'), 
                  (p.get_x() + p.get_width() / 2., p.get_height()), 
                  ha='center', va='center', 
                  xytext=(0, 9), 
                  textcoords='offset points')


plt.show()
# Out:
# /var/folders/ss/_99xspms5kx2w1n6qb7bmdsh0000gn/T/ipykernel_67758/3260942313.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.countplot(x='target', data=data, palette=custom_palette)

# %% [markdown]
# # **11. Find the Count of Male and Female in the Dataset.**

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# **Sex Column is used to find the Male and Female**

# %%
data['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %% [markdown]
# **1--> Male and 0--> Female**

# %% [markdown]
# **TO VISUALIZE THE DATA WE USE SEABORN**

# %%
sns.countplot(x='sex',data=data,palette=custom_palette)
plt.xticks([0,1],['Female','Male'])
plt.ylabel('Total Number of People')
plt.show()
# Out:
# /var/folders/ss/_99xspms5kx2w1n6qb7bmdsh0000gn/T/ipykernel_67758/2842589917.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=data,palette=custom_palette)

# %% [markdown]
# # **12. Find Gender disrtibution According to the Target Variable**

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='sex',hue='target',data=data)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# # **13. Check Age Distribution in the Dataset.**

# %%
sns.distplot(data['age'],bins=20)
plt.show()
# Out:
# /var/folders/ss/_99xspms5kx2w1n6qb7bmdsh0000gn/T/ipykernel_67758/4281029158.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'],bins=20)

# %% [markdown]
# # **14. Check Chest Pain Type.**
#
#   **>chest pain type(4 values)**
#
#    **■ Value 0: typical angina**
#
#    **■ Value 1: atypical angina**
#
#    **■ Value 2: non-anginal pain**
#
#    **■ Value 3: asymptomatic**

# %% [markdown]
# ### **Which Chest Pain type is most common ?**

# %%
 sns.countplot(x='cp' , data=data, palette='Set1')
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic"])
plt.xticks(rotation=75)
 plt.show()
# Out:
# /var/folders/ss/_99xspms5kx2w1n6qb7bmdsh0000gn/T/ipykernel_67758/1496212999.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='cp' , data=data, palette='Set1')

# %% [markdown]
# # **15. Show the Chest Pain Distribution As Per Target Variable.**

# %%
  data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='cp',hue='target',data=data)
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic"])
plt.xticks(rotation=75)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
#  # **16. Show Fasting Blood Sugar Distribution According to the Target Variable.**

# %%
sns.countplot(x='fbs',hue='target',data=data)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
#    # **17. Check Resting Blood Pressure Distribution**

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['trestbps'].hist()
plt.show()

# %% [markdown]
# # **18. Compare Resting Blood Pressure AS Per Sex Column**

# %%
 g=sns.FacetGrid(data,hue="sex",aspect=4)
 g.map(sns.kdeplot,'trestbps',fill=True)
plt.legend(labels=['Male','Female'])
plt.show()

# %% [markdown]
# # **19. Show Distribution of Serum Cholesterol.**

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['chol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # **20. Plot Continous Variables.**

# %% [markdown]
# ### **Find contionous variable and categorial variable.**

# %%
cate_val=[]
cont_val=[]

for column in data.columns:
    if data[column].nunique() <=10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
data.hist(cont_val,figsize=(15,6))
plt.tight_layout()
plt.show()
